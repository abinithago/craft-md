# %%
from huggingface_hub import login
import pandas as pd
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from tqdm import tqdm

def classify_clinical_cases_with_llm(df, text_column, batch_size=16):
    """
    Classify clinical cases as gendered or ungendered using a large language model with optimized batch processing.

    Args:
        df (pd.DataFrame): DataFrame containing clinical case text.
        text_column (str): Column name containing the clinical text.
        batch_size (int): Number of rows to process in a batch.

    Returns:
        pd.DataFrame: DataFrame with a new column 'case_type' indicating 'gendered' or 'ungendered'.
    """
    hf_token = "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"
    login(hf_token, add_to_git_credential=True)

    model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

    # Load model and tokenizer
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = AutoModelForCausalLM.from_pretrained(model_id, torch_dtype=torch.bfloat16).to(device)
    tokenizer = AutoTokenizer.from_pretrained(model_id)

    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token

    def classify_batch(texts):
        # Create prompts for the batch
        prompts = [
            f"Classify the following clinical case as 'gendered' or 'ungendered'. "
            f"If the text refers to gender-specific conditions or anatomy (e.g., genitalia, ovarian cancer, pregnancy), "
            f"it should be marked as 'gendered'. Otherwise, mark it as 'ungendered'.\n\n"
            f"Clinical text: {text}\n"
            f"Case type:"
            for text in texts
        ]

        # Tokenize and process the batch
        inputs = tokenizer(prompts, return_tensors="pt", padding=True, truncation=True).to(device)
        outputs = model.generate(**inputs, max_new_tokens=50)

        # Decode responses
        responses = tokenizer.batch_decode(outputs, skip_special_tokens=True)
        classifications = []
        for response in responses:
            if " gendered" in response.lower():
                classifications.append("gendered")
            elif " ungendered" in response.lower():
                classifications.append("ungendered")
            else:
                classifications.append("ungendered")
        return classifications

    # Process in batches
    texts = df[text_column].tolist()
    case_types = []
    for i in tqdm(range(0, len(texts), batch_size)):
        batch_texts = texts[i:i + batch_size]
        case_types.extend(classify_batch(batch_texts))

    # Add results to DataFrame
    df['case_type'] = case_types
    return df

# %%
df = pd.read_csv('craft-md/data/usmle_and_derm_dataset.csv')
result_df = classify_clinical_cases_with_llm(df, 'case_vignette', batch_size=2)
print(result_df)
# Out:
# Loading checkpoint shards: 100%|██████████| 4/4 [00:01<00:00,  2.97it/s]
#   0%|          | 0/1002 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 1/1002 [00:01<23:53,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 2/1002 [00:02<23:46,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 3/1002 [00:04<23:45,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 4/1002 [00:05<23:43,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   0%|          | 5/1002 [00:07<23:32,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 6/1002 [00:08<23:24,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 7/1002 [00:09<23:20,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 8/1002 [00:11<23:22,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 9/1002 [00:12<23:22,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 10/1002 [00:14<23:16,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 11/1002 [00:15<23:10,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|          | 12/1002 [00:16<23:17,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 13/1002 [00:18<23:19,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 14/1002 [00:19<23:08,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   1%|▏         | 15/1002 [00:21<23:07,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 16/1002 [00:22<23:11,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 17/1002 [00:24<23:16,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 18/1002 [00:25<23:13,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 19/1002 [00:26<23:06,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 20/1002 [00:28<23:09,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 21/1002 [00:29<23:07,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 22/1002 [00:31<22:56,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 23/1002 [00:32<22:48,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 24/1002 [00:33<22:52,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   2%|▏         | 25/1002 [00:35<22:53,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 26/1002 [00:36<22:51,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 27/1002 [00:38<22:42,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 28/1002 [00:39<22:45,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 29/1002 [00:40<22:45,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 30/1002 [00:42<22:42,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 31/1002 [00:43<22:38,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 32/1002 [00:45<22:37,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 33/1002 [00:46<22:35,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 34/1002 [00:47<22:34,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   3%|▎         | 35/1002 [00:49<22:26,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 36/1002 [00:50<22:28,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▎         | 37/1002 [00:52<22:29,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 38/1002 [00:53<22:30,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 39/1002 [00:54<22:24,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 40/1002 [00:56<22:23,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 41/1002 [00:57<22:21,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 42/1002 [00:59<22:24,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 43/1002 [01:00<22:17,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 44/1002 [01:01<22:24,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   4%|▍         | 45/1002 [01:03<22:20,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 46/1002 [01:04<22:23,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 47/1002 [01:06<22:14,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 48/1002 [01:07<22:14,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 49/1002 [01:08<22:13,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▍         | 50/1002 [01:10<22:14,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 51/1002 [01:11<22:17,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 52/1002 [01:13<22:17,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 53/1002 [01:14<22:16,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 54/1002 [01:15<22:16,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   5%|▌         | 55/1002 [01:17<22:16,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 56/1002 [01:18<22:13,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 57/1002 [01:20<22:16,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 58/1002 [01:21<22:20,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 59/1002 [01:22<22:04,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 60/1002 [01:24<22:11,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 61/1002 [01:25<22:15,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▌         | 62/1002 [01:27<22:03,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 63/1002 [01:28<22:02,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 64/1002 [01:30<22:07,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   6%|▋         | 65/1002 [01:31<22:07,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 66/1002 [01:32<22:12,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 67/1002 [01:34<22:05,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 68/1002 [01:35<22:13,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 69/1002 [01:37<22:09,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 70/1002 [01:38<22:12,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 71/1002 [01:40<22:07,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 72/1002 [01:41<23:00,  1.48s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 73/1002 [01:43<22:45,  1.47s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 74/1002 [01:44<22:30,  1.46s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   7%|▋         | 75/1002 [01:45<22:20,  1.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 76/1002 [01:47<22:24,  1.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 77/1002 [01:48<22:14,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 78/1002 [01:50<22:12,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 79/1002 [01:51<22:08,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 80/1002 [01:53<22:03,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 81/1002 [01:54<22:02,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 82/1002 [01:56<22:05,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 83/1002 [01:57<21:53,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 84/1002 [01:58<21:56,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   8%|▊         | 85/1002 [02:00<21:51,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▊         | 86/1002 [02:01<21:48,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▊         | 87/1002 [02:03<21:36,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 88/1002 [02:04<21:47,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 89/1002 [02:05<21:42,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 90/1002 [02:07<21:38,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 91/1002 [02:08<21:30,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 92/1002 [02:10<21:27,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 93/1002 [02:11<21:21,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 94/1002 [02:13<21:24,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#   9%|▉         | 95/1002 [02:14<21:25,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 96/1002 [02:15<21:28,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 97/1002 [02:17<21:27,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 98/1002 [02:18<21:45,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 99/1002 [02:20<21:37,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|▉         | 100/1002 [02:21<21:27,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 101/1002 [02:23<21:19,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 102/1002 [02:24<21:30,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 103/1002 [02:25<21:33,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 104/1002 [02:27<21:35,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  10%|█         | 105/1002 [02:28<21:32,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 106/1002 [02:30<21:36,  1.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 107/1002 [02:31<21:36,  1.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 108/1002 [02:33<21:20,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 109/1002 [02:34<21:09,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 110/1002 [02:35<21:03,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 111/1002 [02:37<21:03,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█         | 112/1002 [02:38<21:02,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█▏        | 113/1002 [02:40<20:56,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█▏        | 114/1002 [02:41<21:00,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  11%|█▏        | 115/1002 [02:43<20:56,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 116/1002 [02:44<20:48,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 117/1002 [02:45<20:44,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 118/1002 [02:47<20:45,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 119/1002 [02:48<20:43,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 120/1002 [02:50<20:42,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 121/1002 [02:51<20:39,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 122/1002 [02:52<20:41,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 123/1002 [02:54<20:40,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 124/1002 [02:55<20:45,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  12%|█▏        | 125/1002 [02:57<20:45,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 126/1002 [02:58<20:45,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 127/1002 [02:59<20:41,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 128/1002 [03:01<20:35,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 129/1002 [03:02<20:32,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 130/1002 [03:04<20:31,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 131/1002 [03:05<20:30,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 132/1002 [03:07<20:33,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 133/1002 [03:08<20:26,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 134/1002 [03:09<20:26,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  13%|█▎        | 135/1002 [03:11<20:26,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▎        | 136/1002 [03:12<20:27,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▎        | 137/1002 [03:14<20:26,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 138/1002 [03:15<20:25,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 139/1002 [03:16<20:25,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 140/1002 [03:18<20:20,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 141/1002 [03:19<20:28,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 142/1002 [03:21<20:28,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 143/1002 [03:22<20:43,  1.45s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 144/1002 [03:24<20:38,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  14%|█▍        | 145/1002 [03:25<20:37,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 146/1002 [03:27<20:35,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 147/1002 [03:28<20:34,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 148/1002 [03:29<20:25,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 149/1002 [03:31<20:18,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▍        | 150/1002 [03:32<20:16,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 151/1002 [03:34<20:21,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 152/1002 [03:35<20:15,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 153/1002 [03:37<20:18,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 154/1002 [03:38<20:11,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  15%|█▌        | 155/1002 [03:39<20:12,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 156/1002 [03:41<20:10,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 157/1002 [03:42<20:06,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 158/1002 [03:44<19:57,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 159/1002 [03:45<19:56,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 160/1002 [03:47<19:57,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 161/1002 [03:48<19:59,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▌        | 162/1002 [03:49<19:53,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▋        | 163/1002 [03:51<19:52,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▋        | 164/1002 [03:52<19:45,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  16%|█▋        | 165/1002 [03:54<19:44,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 166/1002 [03:55<19:43,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 167/1002 [03:56<19:48,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 168/1002 [03:58<19:48,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 169/1002 [03:59<19:50,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 170/1002 [04:01<19:45,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 171/1002 [04:02<19:51,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 172/1002 [04:04<19:55,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 173/1002 [04:05<19:50,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 174/1002 [04:07<19:43,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  17%|█▋        | 175/1002 [04:08<19:43,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 176/1002 [04:09<19:38,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 177/1002 [04:11<19:36,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 178/1002 [04:12<19:29,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 179/1002 [04:14<19:28,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 180/1002 [04:15<19:24,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 181/1002 [04:16<19:25,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 182/1002 [04:18<19:24,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 183/1002 [04:19<19:30,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 184/1002 [04:21<19:24,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  18%|█▊        | 185/1002 [04:22<19:27,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▊        | 186/1002 [04:24<19:22,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▊        | 187/1002 [04:25<19:30,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 188/1002 [04:26<19:23,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 189/1002 [04:28<19:21,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 190/1002 [04:29<19:20,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 191/1002 [04:31<19:22,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 192/1002 [04:32<19:15,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 193/1002 [04:34<19:13,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 194/1002 [04:35<19:10,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  19%|█▉        | 195/1002 [04:36<19:12,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 196/1002 [04:38<19:11,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 197/1002 [04:39<19:18,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 198/1002 [04:41<19:15,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 199/1002 [04:42<19:10,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|█▉        | 200/1002 [04:44<19:00,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 201/1002 [04:45<18:58,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 202/1002 [04:46<18:45,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 203/1002 [04:48<18:44,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 204/1002 [04:49<18:41,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  20%|██        | 205/1002 [04:51<18:42,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 206/1002 [04:52<18:48,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 207/1002 [04:53<18:50,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 208/1002 [04:55<18:46,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 209/1002 [04:56<18:48,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 210/1002 [04:58<18:44,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 211/1002 [04:59<18:49,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██        | 212/1002 [05:01<18:46,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██▏       | 213/1002 [05:02<18:45,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██▏       | 214/1002 [05:03<18:45,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  21%|██▏       | 215/1002 [05:05<18:35,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 216/1002 [05:06<18:32,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 217/1002 [05:08<18:37,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 218/1002 [05:09<18:35,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 219/1002 [05:11<18:27,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 220/1002 [05:12<18:25,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 221/1002 [05:13<18:35,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 222/1002 [05:15<18:32,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 223/1002 [05:16<18:25,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 224/1002 [05:18<18:19,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  22%|██▏       | 225/1002 [05:19<18:16,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 226/1002 [05:20<18:15,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 227/1002 [05:22<18:13,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 228/1002 [05:23<18:10,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 229/1002 [05:25<18:09,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 230/1002 [05:26<18:09,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 231/1002 [05:28<18:10,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 232/1002 [05:29<18:06,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 233/1002 [05:30<18:09,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 234/1002 [05:32<18:11,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  23%|██▎       | 235/1002 [05:33<18:07,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▎       | 236/1002 [05:35<18:10,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▎       | 237/1002 [05:36<18:08,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 238/1002 [05:37<18:15,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 239/1002 [05:39<18:07,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 240/1002 [05:40<18:05,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 241/1002 [05:42<18:04,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 242/1002 [05:43<18:05,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 243/1002 [05:45<18:00,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 244/1002 [05:46<17:56,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  24%|██▍       | 245/1002 [05:47<17:57,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▍       | 246/1002 [05:49<17:55,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▍       | 247/1002 [05:50<17:51,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▍       | 248/1002 [05:52<17:48,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▍       | 249/1002 [05:53<17:55,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▍       | 250/1002 [05:55<17:55,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▌       | 251/1002 [05:56<17:49,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▌       | 252/1002 [05:57<17:45,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▌       | 253/1002 [05:59<17:44,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▌       | 254/1002 [06:00<17:47,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  25%|██▌       | 255/1002 [06:02<17:42,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 256/1002 [06:03<17:37,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 257/1002 [06:04<17:37,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 258/1002 [06:06<17:37,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 259/1002 [06:07<17:33,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 260/1002 [06:09<17:37,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 261/1002 [06:10<17:39,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 262/1002 [06:12<17:37,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▌       | 263/1002 [06:13<17:32,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▋       | 264/1002 [06:14<17:27,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  26%|██▋       | 265/1002 [06:16<17:30,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 266/1002 [06:17<17:28,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 267/1002 [06:19<17:23,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 268/1002 [06:20<17:22,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 269/1002 [06:22<17:27,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 270/1002 [06:23<17:28,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 271/1002 [06:24<17:21,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 272/1002 [06:26<17:16,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 273/1002 [06:27<17:14,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 274/1002 [06:29<17:15,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  27%|██▋       | 275/1002 [06:30<17:16,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 276/1002 [06:32<17:10,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 277/1002 [06:33<17:08,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 278/1002 [06:34<17:11,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 279/1002 [06:36<17:09,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 280/1002 [06:37<17:05,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 281/1002 [06:39<17:07,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 282/1002 [06:40<17:11,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 283/1002 [06:42<17:03,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 284/1002 [06:43<17:05,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  28%|██▊       | 285/1002 [06:44<17:14,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▊       | 286/1002 [06:46<17:09,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▊       | 287/1002 [06:47<17:02,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▊       | 288/1002 [06:49<16:57,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▉       | 289/1002 [06:50<16:59,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▉       | 290/1002 [06:52<16:58,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▉       | 291/1002 [06:53<16:53,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▉       | 292/1002 [06:54<16:48,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▉       | 293/1002 [06:56<16:47,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▉       | 294/1002 [06:57<16:43,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  29%|██▉       | 295/1002 [06:59<16:41,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|██▉       | 296/1002 [07:00<16:34,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|██▉       | 297/1002 [07:01<16:38,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|██▉       | 298/1002 [07:03<16:34,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|██▉       | 299/1002 [07:04<16:30,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|██▉       | 300/1002 [07:06<16:32,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|███       | 301/1002 [07:07<16:37,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|███       | 302/1002 [07:09<16:36,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|███       | 303/1002 [07:10<16:34,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|███       | 304/1002 [07:11<16:31,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  30%|███       | 305/1002 [07:13<16:34,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 306/1002 [07:14<16:29,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 307/1002 [07:16<16:24,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 308/1002 [07:17<16:26,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 309/1002 [07:19<16:26,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 310/1002 [07:20<16:23,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 311/1002 [07:21<16:25,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 312/1002 [07:23<16:26,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███       | 313/1002 [07:24<16:28,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███▏      | 314/1002 [07:26<16:24,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  31%|███▏      | 315/1002 [07:27<16:20,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 316/1002 [07:29<16:21,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 317/1002 [07:30<16:22,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 318/1002 [07:31<16:19,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 319/1002 [07:33<16:17,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 320/1002 [07:34<16:19,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 321/1002 [07:36<16:19,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 322/1002 [07:37<16:14,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 323/1002 [07:39<16:11,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 324/1002 [07:40<16:12,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  32%|███▏      | 325/1002 [07:41<16:12,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 326/1002 [07:43<16:05,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 327/1002 [07:44<16:04,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 328/1002 [07:46<16:04,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 329/1002 [07:47<16:07,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 330/1002 [07:49<16:02,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 331/1002 [07:50<16:00,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 332/1002 [07:51<16:00,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 333/1002 [07:53<16:01,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 334/1002 [07:54<16:01,  1.44s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  33%|███▎      | 335/1002 [07:56<15:54,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▎      | 336/1002 [07:57<15:50,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▎      | 337/1002 [07:59<15:46,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▎      | 338/1002 [08:00<15:39,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▍      | 339/1002 [08:01<15:32,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▍      | 340/1002 [08:03<15:31,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▍      | 341/1002 [08:04<15:29,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▍      | 342/1002 [08:06<15:24,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▍      | 343/1002 [08:07<15:17,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▍      | 344/1002 [08:08<15:19,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  34%|███▍      | 345/1002 [08:10<15:16,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▍      | 346/1002 [08:11<15:17,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▍      | 347/1002 [08:13<15:15,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▍      | 348/1002 [08:14<15:16,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▍      | 349/1002 [08:15<15:15,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▍      | 350/1002 [08:17<15:11,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▌      | 351/1002 [08:18<15:08,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▌      | 352/1002 [08:20<15:10,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▌      | 353/1002 [08:21<15:07,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▌      | 354/1002 [08:22<15:05,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  35%|███▌      | 355/1002 [08:24<14:59,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▌      | 356/1002 [08:25<14:59,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▌      | 357/1002 [08:27<14:58,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▌      | 358/1002 [08:28<14:56,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▌      | 359/1002 [08:29<14:51,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▌      | 360/1002 [08:31<14:51,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▌      | 361/1002 [08:32<14:50,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▌      | 362/1002 [08:33<14:48,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▌      | 363/1002 [08:35<14:48,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▋      | 364/1002 [08:36<14:47,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  36%|███▋      | 365/1002 [08:38<14:49,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 366/1002 [08:39<14:45,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 367/1002 [08:40<14:41,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 368/1002 [08:42<14:43,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 369/1002 [08:43<14:45,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 370/1002 [08:45<14:42,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 371/1002 [08:46<14:38,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 372/1002 [08:47<14:44,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 373/1002 [08:49<14:47,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 374/1002 [08:50<14:41,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  37%|███▋      | 375/1002 [08:52<14:34,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 376/1002 [08:53<14:32,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 377/1002 [08:54<14:37,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 378/1002 [08:56<14:33,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 379/1002 [08:57<14:30,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 380/1002 [08:59<14:27,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 381/1002 [09:00<14:44,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 382/1002 [09:02<14:41,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 383/1002 [09:03<14:35,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 384/1002 [09:04<14:30,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  38%|███▊      | 385/1002 [09:06<14:36,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  39%|███▊      | 386/1002 [09:07<14:34,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  39%|███▊      | 387/1002 [09:09<14:29,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  39%|███▊      | 388/1002 [09:10<14:25,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  39%|███▉      | 389/1002 [09:11<14:30,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ...
#  91%|█████████▏| 916/1002 [21:37<02:02,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 917/1002 [21:39<02:01,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 918/1002 [21:40<01:59,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 919/1002 [21:41<01:58,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 920/1002 [21:43<01:57,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 921/1002 [21:44<01:54,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 922/1002 [21:46<01:53,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 923/1002 [21:47<01:52,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 924/1002 [21:49<01:50,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 925/1002 [21:50<01:48,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  92%|█████████▏| 926/1002 [21:51<01:47,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 927/1002 [21:53<01:46,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 928/1002 [21:54<01:44,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 929/1002 [21:56<01:43,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 930/1002 [21:57<01:41,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 931/1002 [21:58<01:40,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 932/1002 [22:00<01:38,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 933/1002 [22:01<01:37,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 934/1002 [22:03<01:35,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 935/1002 [22:04<01:34,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  93%|█████████▎| 936/1002 [22:05<01:33,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 937/1002 [22:07<01:31,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 938/1002 [22:08<01:30,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▎| 939/1002 [22:10<01:29,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 940/1002 [22:11<01:27,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 941/1002 [22:13<01:25,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 942/1002 [22:14<01:24,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 943/1002 [22:15<01:23,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 944/1002 [22:17<01:22,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 945/1002 [22:18<01:20,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  94%|█████████▍| 946/1002 [22:20<01:18,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 947/1002 [22:21<01:17,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 948/1002 [22:22<01:15,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 949/1002 [22:24<01:14,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 950/1002 [22:25<01:13,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▍| 951/1002 [22:27<01:11,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 952/1002 [22:28<01:10,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 953/1002 [22:29<01:08,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 954/1002 [22:31<01:07,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 955/1002 [22:32<01:06,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  95%|█████████▌| 956/1002 [22:34<01:05,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 957/1002 [22:35<01:03,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 958/1002 [22:36<01:02,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 959/1002 [22:38<01:00,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 960/1002 [22:39<00:59,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 961/1002 [22:41<00:58,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 962/1002 [22:42<00:57,  1.43s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 963/1002 [22:44<00:55,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▌| 964/1002 [22:45<00:54,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 965/1002 [22:46<00:52,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  96%|█████████▋| 966/1002 [22:48<00:51,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 967/1002 [22:49<00:49,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 968/1002 [22:51<00:48,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 969/1002 [22:52<00:46,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 970/1002 [22:54<00:45,  1.42s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 971/1002 [22:55<00:43,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 972/1002 [22:56<00:42,  1.41s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 973/1002 [22:58<00:40,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 974/1002 [22:59<00:39,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 975/1002 [23:00<00:37,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  97%|█████████▋| 976/1002 [23:02<00:36,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 977/1002 [23:03<00:34,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 978/1002 [23:05<00:33,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 979/1002 [23:06<00:32,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 980/1002 [23:07<00:30,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 981/1002 [23:09<00:29,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 982/1002 [23:10<00:27,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 983/1002 [23:12<00:26,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 984/1002 [23:13<00:25,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 985/1002 [23:14<00:23,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  98%|█████████▊| 986/1002 [23:16<00:22,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 987/1002 [23:17<00:20,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 988/1002 [23:19<00:19,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▊| 989/1002 [23:20<00:18,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 990/1002 [23:21<00:16,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 991/1002 [23:23<00:15,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 992/1002 [23:24<00:13,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 993/1002 [23:26<00:12,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 994/1002 [23:27<00:11,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 995/1002 [23:28<00:09,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
#  99%|█████████▉| 996/1002 [23:30<00:08,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 997/1002 [23:31<00:06,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 998/1002 [23:33<00:05,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 999/1002 [23:34<00:04,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1000/1002 [23:35<00:02,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|█████████▉| 1001/1002 [23:37<00:01,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 100%|██████████| 1002/1002 [23:38<00:00,  1.42s/it]
#       Unnamed: 0                                      case_vignette  \
# 0              0  A 22-year-old man presented with complaints of...
# 1              1  A 51-year-old white man presents to the clinic...
# 2              2  An 8-year-old male child is brought to the cli...
# 3              3  A 24-year-old white female graduate student pr...
# 4              4  A 20-year-old woman presents to the clinic wit...
# ...          ...                                                ...
# 1999        3879  A previously healthy 28-year-old man presents ...
# 2000        3893  A 21-year-old male presents to the ED with a s...
# 2001        3896  A 4-year-old boy presents to the opthalmologis...
# 2002        3897  A 55-year-old female is hospitalized following...
# 2003        3912  A 76-year-old woman presents to her primary ca...
#
#                                                choice_1  \
# 0                              Lymphogranuloma venereum
# 1                  Acrodermatitis continua of Hallopeau
# 2                                             Varicella
# 3                                   Perioral dermatitis
# 4                                            Halo nevus
# ...                                                 ...
# 1999                                           Figure A
# 2000  Right-sided tactile, vibration, and propriocep...
# 2001                                     Homocystinuria
# 2002                  Gram-positive bacterial infection
# 2003                                    Lumbar puncture
#
#                                                choice_2  \
# 0                                                Herpes
# 1                                      Herpetic whitlow
# 2                              Gianotti-Crosti syndrome
# 3                                         Acne vulgaris
# 4                                              Melanoma
# ...                                                 ...
# 1999                                           Figure C
# 2000  Left-sided tactile, vibration, and propriocept...
# 2001                                    Marfan syndrome
# 2002                                    Viral infection
# 2003                                         Craniotomy
#
#                                                choice_3  \
# 0                                             Chancroid
# 1                                            Paronychia
# 2                         Langerhans cell histiocytosis
# 3                           Allergic contact dermatitis
# 4                                              Vitiligo
# ...                                                 ...
# 1999                                           Figure B
# 2000  Right-sided tactile, vibration, and propriocep...
# 2001                                Maple syrup disease
# 2002                              Adrenal insufficiency
# 2003                                      Thrombolytics
#
#                                                choice_4  \
# 0                                              Syphilis
# 1                              Acute contact dermatitis
# 2         Pityriasis lichenoides et varioliformis acuta
# 3                                    Facial demodicosis
# 4                                      Dysplastic nevus
# ...                                                 ...
# 1999                                           Figure E
# 2000  Right-sided tactile, vibration, and propriocep...
# 2001                                    Phenylketonuria
# 2002                  Gram-negative bacterial infection
# 2003                                 High dose steroids
#
#                                                  answer  \
# 0                              Lymphogranuloma venereum
# 1                              Acute contact dermatitis
# 2         Pityriasis lichenoides et varioliformis acuta
# 3                                   Perioral dermatitis
# 4                                            Halo nevus
# ...                                                 ...
# 1999                                           Figure B
# 2000  Right-sided tactile, vibration, and propriocep...
# 2001                                     Homocystinuria
# 2002                  Gram-negative bacterial infection
# 2003                                 High dose steroids
#
#                      category             dataset    case_id   case_type
# 0                 Dermatology  dermatology_public     case_0    gendered
# 1                 Dermatology  dermatology_public     case_1  ungendered
# 2                 Dermatology  dermatology_public     case_2  ungendered
# 3                 Dermatology  dermatology_public     case_3  ungendered
# 4                 Dermatology  dermatology_public     case_4  ungendered
# ...                       ...                 ...        ...         ...
# 1999  Gastrointestinal System         MedQA_USMLE  case_3879  ungendered
# 2000                    Other         MedQA_USMLE  case_3893  ungendered
# 2001                    Other         MedQA_USMLE  case_3896    gendered
# 2002                    Other         MedQA_USMLE  case_3897  ungendered
# 2003             Rheumatology         MedQA_USMLE  case_3912    gendered
#
# [2004 rows x 11 columns]

# %%
result_df
# Out:
#       Unnamed: 0                                      case_vignette  \
# 0              0  A 22-year-old man presented with complaints of...
# 1              1  A 51-year-old white man presents to the clinic...
# 2              2  An 8-year-old male child is brought to the cli...
# 3              3  A 24-year-old white female graduate student pr...
# 4              4  A 20-year-old woman presents to the clinic wit...
# ...          ...                                                ...
# 1999        3879  A previously healthy 28-year-old man presents ...
# 2000        3893  A 21-year-old male presents to the ED with a s...
# 2001        3896  A 4-year-old boy presents to the opthalmologis...
# 2002        3897  A 55-year-old female is hospitalized following...
# 2003        3912  A 76-year-old woman presents to her primary ca...
#
#                                                choice_1  \
# 0                              Lymphogranuloma venereum
# 1                  Acrodermatitis continua of Hallopeau
# 2                                             Varicella
# 3                                   Perioral dermatitis
# 4                                            Halo nevus
# ...                                                 ...
# 1999                                           Figure A
# 2000  Right-sided tactile, vibration, and propriocep...
# 2001                                     Homocystinuria
# 2002                  Gram-positive bacterial infection
# 2003                                    Lumbar puncture
#
#                                                choice_2  \
# 0                                                Herpes
# 1                                      Herpetic whitlow
# 2                              Gianotti-Crosti syndrome
# 3                                         Acne vulgaris
# 4                                              Melanoma
# ...                                                 ...
# 1999                                           Figure C
# 2000  Left-sided tactile, vibration, and propriocept...
# 2001                                    Marfan syndrome
# 2002                                    Viral infection
# 2003                                         Craniotomy
#
#                                                choice_3  \
# 0                                             Chancroid
# 1                                            Paronychia
# 2                         Langerhans cell histiocytosis
# 3                           Allergic contact dermatitis
# 4                                              Vitiligo
# ...                                                 ...
# 1999                                           Figure B
# 2000  Right-sided tactile, vibration, and propriocep...
# 2001                                Maple syrup disease
# 2002                              Adrenal insufficiency
# 2003                                      Thrombolytics
#
#                                                choice_4  \
# 0                                              Syphilis
# 1                              Acute contact dermatitis
# 2         Pityriasis lichenoides et varioliformis acuta
# 3                                    Facial demodicosis
# 4                                      Dysplastic nevus
# ...                                                 ...
# 1999                                           Figure E
# 2000  Right-sided tactile, vibration, and propriocep...
# 2001                                    Phenylketonuria
# 2002                  Gram-negative bacterial infection
# 2003                                 High dose steroids
#
#                                                  answer  \
# 0                              Lymphogranuloma venereum
# 1                              Acute contact dermatitis
# 2         Pityriasis lichenoides et varioliformis acuta
# 3                                   Perioral dermatitis
# 4                                            Halo nevus
# ...                                                 ...
# 1999                                           Figure B
# 2000  Right-sided tactile, vibration, and propriocep...
# 2001                                     Homocystinuria
# 2002                  Gram-negative bacterial infection
# 2003                                 High dose steroids
#
#                      category             dataset    case_id   case_type
# 0                 Dermatology  dermatology_public     case_0    gendered
# 1                 Dermatology  dermatology_public     case_1  ungendered
# 2                 Dermatology  dermatology_public     case_2  ungendered
# 3                 Dermatology  dermatology_public     case_3  ungendered
# 4                 Dermatology  dermatology_public     case_4  ungendered
# ...                       ...                 ...        ...         ...
# 1999  Gastrointestinal System         MedQA_USMLE  case_3879  ungendered
# 2000                    Other         MedQA_USMLE  case_3893  ungendered
# 2001                    Other         MedQA_USMLE  case_3896    gendered
# 2002                    Other         MedQA_USMLE  case_3897  ungendered
# 2003             Rheumatology         MedQA_USMLE  case_3912    gendered
#
# [2004 rows x 11 columns]

# %%
import pandas as pd

df = pd.read_csv('craft-md/data_augmented/baseline.csv')
result_df = df[df['case_type']=='ungendered']

result_df.to_csv('craft-md/data_augmented/baseline_ungendered.csv')

# %% [markdown]
# # Gender Swapping

# %%
import os
from openai import AzureOpenAI
import pandas as pd 
import numpy as np
import argparse
import random
import json
from tqdm import tqdm
import datetime
import string
import math
import sys 

def random_perturbations(text, type_pert, prob):

  random.seed(0)
  assert type(text) == str
  list_chars = list(text)

  if type_pert=="lowercase":
    for i in range(len(list_chars)):
      char_value = random.choices([list_chars[i].lower(), list_chars[i]], weights=[prob, 1-prob], k=1)[0]
      list_chars[i] = char_value

  if type_pert=="uppercase":
    for i in range(len(list_chars)):
      char_value = random.choices([list_chars[i].upper(), list_chars[i]], weights=[prob, 1-prob], k=1)[0]
      list_chars[i] = char_value

  if type_pert=="exclamation":
    indices = [i for i, letter in enumerate(list_chars) if letter == "."]
    for i in indices:
      char_value = random.choices(["!", "."], weights=[prob, 1-prob], k=1)[0]
      list_chars[i] = char_value
  
  if type_pert == "typo":
    # Get the indices of all non-space characters
    nonspace_indices = [i for i, char in enumerate(list_chars) if not char.isspace()]

    # Calculate the number of indices to flip based on the probability
    num_indices = math.floor(len(nonspace_indices) * prob)
    
    # Randomly select indices to flip
    flipping_indices = random.sample(nonspace_indices, k=num_indices)
    
    # Perform the flips
    for i in flipping_indices:
      # Randomly choose a replacement character from the alphabet
      list_chars[i] = random.choice(string.ascii_letters)

  if type_pert == "whitespace":
    new_text = []
    for char in list_chars:
        # Randomly add whitespace before the character
        add_space = random.choices([True, False], weights=[prob, 1-prob], k=1)[0]
        if add_space:
            whitespace = " " * random.randint(1, 3)  # Add 1 to 3 spaces
            new_text.append(whitespace)
        new_text.append(char)
    list_chars = new_text

  return "".join(list_chars)

def regex_perturb(df, attribute, probability):
  """
  gender swap using regex 
  """
  perturbed_messages = []
  for i, row in df.iterrows(): 
    perturbed_text = random_perturbations(row['case_vignette'], attribute, probability)
    perturbed_messages.append(perturbed_text)

  df['case_vignette'] = [r for r in perturbed_messages]
  return df

# %%
baseline_df = pd.read_csv('/data/healthy-ml/scratch/abinitha/craft-md/craft-md/data_augmented/baseline.csv')
lowercase_df = regex_perturb(baseline_df, 'typo', 0.03)
lowercase_df.to_csv('/data/healthy-ml/scratch/abinitha/craft-md/craft-md/data_augmented/typo.csv')
